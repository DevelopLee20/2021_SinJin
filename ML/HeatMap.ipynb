# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('match_stats_Lee.csv')

# %%
col_lst = list(df.columns)
df.shape
# Out:
# (91806, 41)

# %%
for i in range(0,41,5)
ax = sns.heatmap(df.corr(), annot=True)

# %%
# Out:
# 'match_duration'
