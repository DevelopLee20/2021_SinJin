# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/cslab/Desktop/vscoding/Project_JoNel/ML_Test/Use.csv')
df.head(3)
# Out:
#    winner_games_won  loser_games_won  winner_tiebreaks_won  \
# 0                13               11                     0
# 1                13               10                     1
# 2                13                9                     0
#
#    loser_tiebreaks_won  winner_aces  winner_double_faults  \
# 0                    0          1.0                   2.0
# 1                    0          7.0                   4.0
# 2                    0          3.0                   0.0
#
#    winner_first_serves_in  winner_first_serves_total  \
# 0                    44.0                       65.0
# 1                    37.0                       80.0
# 2                     0.0                       65.0
#
#    winner_first_serve_points_won  winner_first_serve_points_total  ...  \
# 0                           31.0                             44.0  ...
# 1                           26.0                             37.0  ...
# ...

# %%
col_lst = list(df.columns)
df.shape
# Out:
# (91939, 55)

# %%
dff = df.values
dff = pd.DataFrame(dff, columns=col_lst)

cor = dff.corr()

ax = sns.heatmap(cor, annot=True)

# %%
cor
# Out:
#                                   winner_games_won  loser_games_won  \
# winner_games_won                          1.000000         0.822229
# loser_games_won                           0.822229         1.000000
# winner_tiebreaks_won                      0.227321         0.417631
# loser_tiebreaks_won                       0.468479         0.380761
# winner_aces                               0.391231         0.379134
# winner_double_faults                      0.381079         0.427097
# winner_first_serves_in                    0.754978         0.778883
# winner_first_serves_total                 0.844966         0.877833
# winner_first_serve_points_won             0.824109         0.814456
# winner_first_serve_points_total           0.805372         0.826163
# winner_second_serve_points_won            0.674918         0.685660
# winner_second_serve_points_total          0.715007         0.757909
# winner_break_points_saved                 0.391505         0.456055
# ...

# %%
cor.to_csv('Test.csv')
